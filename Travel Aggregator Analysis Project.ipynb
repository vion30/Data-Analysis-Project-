# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# _*Travel Aggregator Analysis*_
# Certification Project
#
# Scenario
# Travelling has significantly changed thanks to technology. In the earlier days, it was not
# easy to travel as booking journeys used to be a hassle, where people needed to contact
# travel agents, get prices and then do a lot of paperwork.
# But, with the advent of online apps, it becomes easier to book tickets. However, one
# challenge is still there. Due to many available apps which offer bookings, there can be a lot
# of comparisons for getting the best price.
# A new Indian start-up, "MyNextBooking” is an aggregator on top of the available top
# platforms (Yatra, MMT, Goibibo). It helps the user compare prices for their upcoming
# journeys on its platform and the customer is redirected to the desired platform after
# looking at the price.
# However, they need to do a lot of analysis of the data which they have collected over a
# while.
# As a newly hired analyst and proficiency in Python, your role is to help them perform an indepth analysis.

# %% [markdown]
# About the Data: The data provided consists of the following two files:
# 1) Bookings.csv
# • customer_id
# • booking_id
# • from_city
# Data Science and Machine Learning Program
# 4
# • from_country
# • to_city
# • to_country
# • booking_time
# • device_type_used
# • INR_Amount
# • service_name
# • no_of_passengers
# • days_to_departure
# • distance_km
# 2) Sessions.csv
# • session_id
# • search_id
# • search_time
# • session_starting_time
# • booking_id

# %% [markdown]
# Objective: Please provide answers to the following questions:
# 1) Find the number of distinct bookings, sessions, and searches from the given data
# sets.
# 2) How many sessions have more than one booking?
# 3) Which days of the week have the highest number of bookings? Also, draw a pie
# chart to show the distribution for all days of the week?
# 4) For each of the service names, display the total number of bookings and the total
# Gross Booking Value in INR.
# Data Science and Machine Learning Program
# 3
# 5) For customers who have more than 1 booking, which is the most booked route
# (from_city to to_city)?
# 6) Which are the top 3 departure cities from where customers book mostly in advance,
# provided that there have been at least 5 departures from that city?
# 7) Plot a heatmap displaying correlations of the numerical column and report which
# pair of numerical columns in the bookings data set, have the maximum correlation?
# 8) For each service, which is the most used device type for making bookings on the
# platform?
# 9) Plot the trends at a quarterly frequency for the number of bookings by each of the
# device types, that is, plot a time series for each year and quarter showing the
# number of bookings performed by each device type.
# 10) Consider the following example:
# 12 customers performed a total of 100 searches but only a few of them performed
# 10 bookings in total.
# Searches = 100 bookings = 10 customers = 12
# The overall booking to search ratio, Ober, is 10/100 = 0.1 Using the above
# information/context, answer the following:
# • What is the average oBSR for each month of the year?
# -• What is the average oBSR for each day of the week?
# • Plot a time series of oBSR on all the given dates.

# %%
booking = pd.read_csv("bookings.csv")
session = pd.read_csv("sessions.csv")

# %%
booking
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %%
booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        339 non-null    object
#  1   booking_id         339 non-null    object
#  2   from_city          339 non-null    object
#  3   from_country       339 non-null    object
#  4   to_city            339 non-null    object
#  5   to_country         339 non-null    object
#  6   booking_time       339 non-null    object
#  7   device_type_used   339 non-null    object
#  8   INR_Amount         339 non-null    float64
#  9   service_name       339 non-null    object
#  10  no_of_passengers   339 non-null    float64
#  11  days_to_departure  339 non-null    float64
#  12  distance_km        339 non-null    float64
# dtypes: float64(4), object(9)
# memory usage: 34.6+ KB

# %%
session
# Out:
#        session_id    search_id               search_time  \
# 0     session_322   search_784  2020-01-21T21:35:38.910Z
# 1     session_322   search_776  2020-01-21T21:37:37.697Z
# 2     session_322   search_623  2020-01-21T21:36:11.392Z
# 3     session_322   search_270  2020-01-21T21:16:07.685Z
# 4     session_322   search_905  2020-01-21T21:34:55.673Z
# ...           ...          ...                       ...
# 1492  session_150   search_156  2018-12-18T22:59:43.764Z
# 1493  session_120  search_1096      2021-12-23T17:29:37Z
# 1494  session_120   search_962      2021-12-23T17:34:39Z
# 1495  session_150  search_1306  2018-12-18T22:52:37.654Z
# 1496  session_120  search_1180      2021-12-23T17:34:52Z
#
#          session_starting_time   booking_id
# 0         2020-01-21T21:10:12Z          NaN
# 1         2020-01-21T21:10:12Z          NaN
# 2         2020-01-21T21:10:12Z          NaN
# 3         2020-01-21T21:10:12Z          NaN
# 4         2020-01-21T21:10:12Z          NaN
# ...

# %%
session.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   session_id             1497 non-null   object
#  1   search_id              1497 non-null   object
#  2   search_time            1497 non-null   object
#  3   session_starting_time  1497 non-null   object
#  4   booking_id             366 non-null    object
# dtypes: object(5)
# memory usage: 58.6+ KB

# %%
booking.isnull().any()
# Out:
# customer_id          False
# booking_id           False
# from_city            False
# from_country         False
# to_city              False
# to_country           False
# booking_time         False
# device_type_used     False
# INR_Amount           False
# service_name         False
# no_of_passengers     False
# days_to_departure    False
# distance_km          False
# dtype: bool

# %%
session.isnull().any()
# Out:
# session_id               False
# search_id                False
# search_time              False
# session_starting_time    False
# booking_id                True
# dtype: bool

# %%
# 1) Find the number of distinct bookings, sessions, and searches from the given data sets.

distinct_bookings = booking['booking_id'].nunique()
print("Distinct Bookings :" , distinct_bookings)

distinct_sessions = session['session_id'].nunique()
print("Distinct Sessions :" , distinct_sessions)

distinct_searches = session['search_id'].nunique()
print("Distinct Searches :" , distinct_searches)
# Out:
# Distinct Bookings : 339
# Distinct Sessions : 331
# Distinct Searches : 1360

# %%
booking.duplicated().any()
# Out:
# False

# %%
booking['booking_id'].duplicated().any()
# Out:
# False

# %%
booking['customer_id'].duplicated().any()
# Out:
# True

# %%
booking['customer_id'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 334    False
# 335     True
# 336    False
# 337    False
# 338    False
# Name: customer_id, Length: 339, dtype: bool

# %%
booking.drop_duplicates(['customer_id'],inplace= True)

# %%
booking['customer_id'].duplicated().any()
# Out:
# False

# %%
session.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   session_id             1497 non-null   object
#  1   search_id              1497 non-null   object
#  2   search_time            1497 non-null   object
#  3   session_starting_time  1497 non-null   object
#  4   booking_id             366 non-null    object
# dtypes: object(5)
# memory usage: 58.6+ KB

# %%
session.duplicated().any()
# Out:
# True

# %%
session.session_id.duplicated().any()
# Out:
# True

# %%
session.search_id.duplicated().any()
# Out:
# True

# %%
session.booking_id.duplicated().any()
# Out:
# True

# %%
session.drop_duplicates(['session_id'], inplace = True)

# %%
session.drop_duplicates(['search_id'], inplace = True)

# %%
session.drop_duplicates(['booking_id'], inplace = True)

# %%
session.duplicated().any()
# Out:
# False

# %%
booking.isnull().sum()
# Out:
# customer_id          0
# booking_id           0
# from_city            0
# from_country         0
# to_city              0
# to_country           0
# booking_time         0
# device_type_used     0
# INR_Amount           0
# service_name         0
# no_of_passengers     0
# days_to_departure    0
# distance_km          0
# dtype: int64

# %%
session.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 179 entries, 0 to 1485
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   session_id             179 non-null    object
#  1   search_id              179 non-null    object
#  2   search_time            179 non-null    object
#  3   session_starting_time  179 non-null    object
#  4   booking_id             178 non-null    object
# dtypes: object(5)
# memory usage: 8.4+ KB

# %%
session.isnull().sum()
# Out:
# session_id               0
# search_id                0
# search_time              0
# session_starting_time    0
# booking_id               1
# dtype: int64

# %%
# 1) Find the number of distinct bookings, sessions, and searches from the given data sets.

distinct_bookings = booking['booking_id'].nunique()
print("Distinct Bookings :" , distinct_bookings)

distinct_sessions = session['session_id'].nunique()
print("Distinct Sessions :" , distinct_sessions)

distinct_searches = session['search_id'].nunique()
print("Distinct Searches :" , distinct_searches)
# Out:
# Distinct Bookings : 306
# Distinct Sessions : 179
# Distinct Searches : 179

# %%
booking = pd.read_csv("bookings.csv")
session = pd.read_csv("sessions.csv")

# %%
# 2) How many sessions have more than one booking?

booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        339 non-null    object
#  1   booking_id         339 non-null    object
#  2   from_city          339 non-null    object
#  3   from_country       339 non-null    object
#  4   to_city            339 non-null    object
#  5   to_country         339 non-null    object
#  6   booking_time       339 non-null    object
#  7   device_type_used   339 non-null    object
#  8   INR_Amount         339 non-null    float64
#  9   service_name       339 non-null    object
#  10  no_of_passengers   339 non-null    float64
#  11  days_to_departure  339 non-null    float64
#  12  distance_km        339 non-null    float64
# dtypes: float64(4), object(9)
# memory usage: 34.6+ KB

# %%
session.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   session_id             1497 non-null   object
#  1   search_id              1497 non-null   object
#  2   search_time            1497 non-null   object
#  3   session_starting_time  1497 non-null   object
#  4   booking_id             366 non-null    object
# dtypes: object(5)
# memory usage: 58.6+ KB

# %%
session
# Out:
#        session_id    search_id               search_time  \
# 0     session_322   search_784  2020-01-21T21:35:38.910Z
# 1     session_322   search_776  2020-01-21T21:37:37.697Z
# 2     session_322   search_623  2020-01-21T21:36:11.392Z
# 3     session_322   search_270  2020-01-21T21:16:07.685Z
# 4     session_322   search_905  2020-01-21T21:34:55.673Z
# ...           ...          ...                       ...
# 1492  session_150   search_156  2018-12-18T22:59:43.764Z
# 1493  session_120  search_1096      2021-12-23T17:29:37Z
# 1494  session_120   search_962      2021-12-23T17:34:39Z
# 1495  session_150  search_1306  2018-12-18T22:52:37.654Z
# 1496  session_120  search_1180      2021-12-23T17:34:52Z
#
#          session_starting_time   booking_id
# 0         2020-01-21T21:10:12Z          NaN
# 1         2020-01-21T21:10:12Z          NaN
# 2         2020-01-21T21:10:12Z          NaN
# 3         2020-01-21T21:10:12Z          NaN
# 4         2020-01-21T21:10:12Z          NaN
# ...

# %%
merge_df = session.merge(booking[['booking_id']], on  = 'booking_id', how = 'left')
merge_df
# Out:
#        session_id    search_id               search_time  \
# 0     session_322   search_784  2020-01-21T21:35:38.910Z
# 1     session_322   search_776  2020-01-21T21:37:37.697Z
# 2     session_322   search_623  2020-01-21T21:36:11.392Z
# 3     session_322   search_270  2020-01-21T21:16:07.685Z
# 4     session_322   search_905  2020-01-21T21:34:55.673Z
# ...           ...          ...                       ...
# 1492  session_150   search_156  2018-12-18T22:59:43.764Z
# 1493  session_120  search_1096      2021-12-23T17:29:37Z
# 1494  session_120   search_962      2021-12-23T17:34:39Z
# 1495  session_150  search_1306  2018-12-18T22:52:37.654Z
# 1496  session_120  search_1180      2021-12-23T17:34:52Z
#
#          session_starting_time   booking_id
# 0         2020-01-21T21:10:12Z          NaN
# 1         2020-01-21T21:10:12Z          NaN
# 2         2020-01-21T21:10:12Z          NaN
# 3         2020-01-21T21:10:12Z          NaN
# 4         2020-01-21T21:10:12Z          NaN
# ...

# %%
merge_df = session.merge(booking, on  = 'booking_id', how = 'left')
merge_df
# Out:
#        session_id    search_id               search_time  \
# 0     session_322   search_784  2020-01-21T21:35:38.910Z
# 1     session_322   search_776  2020-01-21T21:37:37.697Z
# 2     session_322   search_623  2020-01-21T21:36:11.392Z
# 3     session_322   search_270  2020-01-21T21:16:07.685Z
# 4     session_322   search_905  2020-01-21T21:34:55.673Z
# ...           ...          ...                       ...
# 1492  session_150   search_156  2018-12-18T22:59:43.764Z
# 1493  session_120  search_1096      2021-12-23T17:29:37Z
# 1494  session_120   search_962      2021-12-23T17:34:39Z
# 1495  session_150  search_1306  2018-12-18T22:52:37.654Z
# 1496  session_120  search_1180      2021-12-23T17:34:52Z
#
#          session_starting_time   booking_id   customer_id  from_city  \
# 0         2020-01-21T21:10:12Z          NaN           NaN        NaN
# 1         2020-01-21T21:10:12Z          NaN           NaN        NaN
# 2         2020-01-21T21:10:12Z          NaN           NaN        NaN
# ...

# %%
booking_per_session = merge_df.groupby('booking_id').agg(bookings_per_session = ('session_id', 'count'))
booking_per_session.value_counts()
# Out:
# bookings_per_session
# 1                       310
# 2                        28
# Name: count, dtype: int64

# %%
print("The number of sessions having more than one bookings : ", booking_per_session[booking_per_session >  1].count())
# Out:
# The number of sessions having more than one bookings :  bookings_per_session    28
# dtype: int64

# %%
# 3) Which days of the week have the highest number of bookings? Also, draw a pie chart to show the distribution for all days of the week?

booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        339 non-null    object
#  1   booking_id         339 non-null    object
#  2   from_city          339 non-null    object
#  3   from_country       339 non-null    object
#  4   to_city            339 non-null    object
#  5   to_country         339 non-null    object
#  6   booking_time       339 non-null    object
#  7   device_type_used   339 non-null    object
#  8   INR_Amount         339 non-null    float64
#  9   service_name       339 non-null    object
#  10  no_of_passengers   339 non-null    float64
#  11  days_to_departure  339 non-null    float64
#  12  distance_km        339 non-null    float64
# dtypes: float64(4), object(9)
# memory usage: 34.6+ KB

# %%
booking.head()
# Out:
#     customer_id   booking_id   from_city from_country            to_city  \
# 0  customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1  customer_303  booking_156       Delhi        India           Brussels
# 2  customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3  customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4  customer_287  booking_222     Gurgaon        India   Roissy-en-France
#
#   to_country          booking_time device_type_used  INR_Amount service_name  \
# 0      India  2020-02-05T16:12:08Z          Desktop     2565.28          MMT
# 1    Belgium  2018-11-21T08:21:47Z          Android    23120.00        YATRA
# 2    Germany  2019-12-16T22:54:58Z          Android    25717.60        YATRA
# 3    Germany  2021-10-29T12:25:38Z          Desktop   135969.60      GOIBIBO
# 4     France  2020-08-11T16:09:10Z          Android    31791.20      GOIBIBO
#
#    no_of_passengers  days_to_departure  distance_km
# ...

# %%
booking['booking_time_clear'] = pd.to_datetime(booking['booking_time'])
booking
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %%
booking['booking_day'] = booking['booking_time_clear'].dt.day_name()
booking
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %%
booking_on_day = booking['booking_day'].value_counts()
booking_on_day.sort_values(ascending = False, inplace = True)

# %%
print('The number bookings on different days are :\n' , booking_on_day)
# Out:
# The number bookings on different days are :
#  booking_day
# Thursday     65
# Tuesday      59
# Monday       51
# Friday       51
# Saturday     44
# Sunday       35
# Wednesday    34
# Name: count, dtype: int64

# %%
print('The most number of bookings are on :' , booking_on_day.idxmax())
# Out:
# The most number of bookings are on : Thursday

# %%
plt.pie(booking_on_day ,labels=booking_on_day.index,startangle=140, radius=2,autopct="%1.1f%%")
plt.pie
# Out:
# <function matplotlib.pyplot.pie(x: 'ArrayLike', explode: 'ArrayLike | None' = None, labels: 'Sequence[str] | None' = None, colors: 'ColorType | Sequence[ColorType] | None' = None, autopct: 'str | Callable[[float], str] | None' = None, pctdistance: 'float' = 0.6, shadow: 'bool' = False, labeldistance: 'float | None' = 1.1, startangle: 'float' = 0, radius: 'float' = 1, counterclock: 'bool' = True, wedgeprops: 'dict[str, Any] | None' = None, textprops: 'dict[str, Any] | None' = None, center: 'tuple[float, float]' = (0, 0), frame: 'bool' = False, rotatelabels: 'bool' = False, *, normalize: 'bool' = True, hatch: 'str | Sequence[str] | None' = None, data=None) -> 'tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]'>

# %%
# 4) For each of the service names, display the total number of bookings and the total Gross Booking Value in INR.

booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         339 non-null    object
#  1   booking_id          339 non-null    object
#  2   from_city           339 non-null    object
#  3   from_country        339 non-null    object
#  4   to_city             339 non-null    object
#  5   to_country          339 non-null    object
#  6   booking_time        339 non-null    object
#  7   device_type_used    339 non-null    object
#  8   INR_Amount          339 non-null    float64
#  9   service_name        339 non-null    object
#  10  no_of_passengers    339 non-null    float64
#  11  days_to_departure   339 non-null    float64
#  12  distance_km         339 non-null    float64
#  13  booking_time_clear  339 non-null    datetime64[ns, UTC]
#  14  booking_day         339 non-null    object
# ...

# %%
print("Total Number of Bookings per Service: \n\n", booking.service_name.value_counts())
# Out:
# Total Number of Bookings per Service:
#
#  service_name
# GOIBIBO    186
# YATRA      105
# MMT         48
# Name: count, dtype: int64

# %%
gross_income_per_service = booking.groupby('service_name').agg(gross_income = ('INR_Amount', 'sum'))
print("\nGross Booking Value (in INR) per Service: \n")
gross_income_per_service
# Out:
# Gross Booking Value (in INR) per Service:
#               gross_income
# service_name
# GOIBIBO         5897637.97
# MMT              665669.08
# YATRA           3378702.13

# %%
# 5) For customers who have more than 1 booking, which is the most booked route (from_city to to_city)?

booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         339 non-null    object
#  1   booking_id          339 non-null    object
#  2   from_city           339 non-null    object
#  3   from_country        339 non-null    object
#  4   to_city             339 non-null    object
#  5   to_country          339 non-null    object
#  6   booking_time        339 non-null    object
#  7   device_type_used    339 non-null    object
#  8   INR_Amount          339 non-null    float64
#  9   service_name        339 non-null    object
#  10  no_of_passengers    339 non-null    float64
#  11  days_to_departure   339 non-null    float64
#  12  distance_km         339 non-null    float64
#  13  booking_time_clear  339 non-null    datetime64[ns, UTC]
#  14  booking_day         339 non-null    object
# ...

# %%
booking_cus = booking.groupby('customer_id').agg( Customer_bookings = ('booking_id', 'count'))
booking_cus.value_counts()
# Out:
# Customer_bookings
# 1                    280
# 2                     20
# 3                      5
# 4                      1
# Name: count, dtype: int64

# %%
booking_cus
# Out:
#               Customer_bookings
# customer_id
# customer_0                    1
# customer_1                    1
# customer_10                   1
# customer_100                  1
# customer_101                  1
# ...                         ...
# customer_95                   1
# customer_96                   1
# customer_97                   4
# customer_98                   1
# customer_99                   1
#
# [306 rows x 1 columns]

# %%
Cust_gt_1_booking = booking_cus[booking_cus['Customer_bookings']>1]
print(Cust_gt_1_booking.info())
Cust_gt_1_booking.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, customer_120 to customer_97
# Data columns (total 1 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer_bookings  26 non-null     int64
# dtypes: int64(1)
# memory usage: 416.0+ bytes
# None
#               Customer_bookings
# customer_id
# customer_120                  2
# customer_137                  2
# customer_144                  2
# customer_155                  2
# customer_160                  3

# %%
Cust_gt_1_booking.value_counts()
# Out:
# Customer_bookings
# 2                    20
# 3                     5
# 4                     1
# Name: count, dtype: int64

# %%
Cust_gt_1_booking_route = Cust_gt_1_booking.merge(booking, on = 'customer_id', how = 'left')
Cust_gt_1_booking_route.head()
# Out:
#     customer_id  Customer_bookings   booking_id from_city from_country  \
# 0  customer_120                  2  booking_151     Delhi        India
# 1  customer_120                  2  booking_299     Jammu        India
# 2  customer_137                  2   booking_88   Gurgaon        India
# 3  customer_137                  2  booking_190   Gurgaon        India
# 4  customer_144                  2  booking_296     Surat        India
#
#       to_city            to_country          booking_time device_type_used  \
# 0       Jammu                 India  2020-02-03T13:56:36Z          Desktop
# 1       Dubai  United Arab Emirates  2020-02-13T18:16:04Z          Desktop
# 2  Birmingham        United Kingdom  2019-12-22T08:49:25Z              IOS
# 3  Rāja Sānsi                 India  2020-01-26T13:38:44Z              IOS
# 4  Devanhalli                 India  2020-02-09T16:50:05Z          Desktop
#
#    INR_Amount service_name  no_of_passengers  days_to_departure  distance_km  \
# ...

# %%
Cust_gt_1_booking_route.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         59 non-null     object
#  1   Customer_bookings   59 non-null     int64
#  2   booking_id          59 non-null     object
#  3   from_city           59 non-null     object
#  4   from_country        59 non-null     object
#  5   to_city             59 non-null     object
#  6   to_country          59 non-null     object
#  7   booking_time        59 non-null     object
#  8   device_type_used    59 non-null     object
#  9   INR_Amount          59 non-null     float64
#  10  service_name        59 non-null     object
#  11  no_of_passengers    59 non-null     float64
#  12  days_to_departure   59 non-null     float64
#  13  distance_km         59 non-null     float64
#  14  booking_time_clear  59 non-null     datetime64[ns, UTC]
# ...

# %%
Cust_gt_1_booking_route['route'] = Cust_gt_1_booking_route['from_city'] + ' to ' + Cust_gt_1_booking_route['to_city']
Cust_gt_1_booking_route
# Out:
#      customer_id  Customer_bookings   booking_id           from_city  \
# 0   customer_120                  2  booking_151               Delhi
# 1   customer_120                  2  booking_299               Jammu
# 2   customer_137                  2   booking_88             Gurgaon
# 3   customer_137                  2  booking_190             Gurgaon
# 4   customer_144                  2  booking_296               Surat
# 5   customer_144                  2  booking_173           Ahmedabad
# 6   customer_155                  2  booking_261              Jaipur
# 7   customer_155                  2   booking_54             Gurgaon
# 8   customer_160                  3  booking_313              Mumbai
# 9   customer_160                  3  booking_122               Patna
# 10  customer_160                  3  booking_278             Gurgaon
# 11  customer_176                  3    booking_2              Barelā
# 12  customer_176                  3  booking_297             Gurgaon
# ...

# %%
Cust_gt_1_booking_route['route'].value_counts()
# Out:
# route
# Gurgaon to Roissy-en-France         5
# Gurgaon to Rāja Sānsi               3
# Gurgaon to Bhubaneswar              2
# Gurgaon to Bagdogra                 2
# Gurgaon to Paris                    2
# Bālāpur to Düsseldorf               2
# Devanhalli to Gurgaon               2
# Durlaga to Bhubaneswar              2
# Gurgaon to Tiruchi                  2
# Gurgaon to Mumbai                   1
# Delhi to Paris                      1
# Gurgaon to Lisbon                   1
# Gurgaon to Fiumicino                1
# Rāja Sānsi to Gurgaon               1
# Madhyamgram to Frankfurt am Main    1
# Kolkata to Gurgaon                  1
# Thiruvananthapuram to London        1
# Indore to Mumbai                    1
# Mumbai to Chicalim                  1
# Bikaner to Gurgaon                  1
# Gurgaon to Berlin                   1
# Dharamsala to Gurgaon               1
# Delhi to Yol                        1
# Pune to Nagpur                      1
# ...

# %%
print("The most booked route is : ",Cust_gt_1_booking_route['route'].value_counts().idxmax())
# Out:
# The most booked route is :  Gurgaon to Roissy-en-France

# %%
# 6) Which are the top3 departure cities from where customers book mostly in advance,provided that there have been at least 5 departures from that city?

booking.head()
# Out:
#     customer_id   booking_id   from_city from_country            to_city  \
# 0  customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1  customer_303  booking_156       Delhi        India           Brussels
# 2  customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3  customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4  customer_287  booking_222     Gurgaon        India   Roissy-en-France
#
#   to_country          booking_time device_type_used  INR_Amount service_name  \
# 0      India  2020-02-05T16:12:08Z          Desktop     2565.28          MMT
# 1    Belgium  2018-11-21T08:21:47Z          Android    23120.00        YATRA
# 2    Germany  2019-12-16T22:54:58Z          Android    25717.60        YATRA
# 3    Germany  2021-10-29T12:25:38Z          Desktop   135969.60      GOIBIBO
# 4     France  2020-08-11T16:09:10Z          Android    31791.20      GOIBIBO
#
# ...

# %%
(booking['days_to_departure']==0).value_counts()
# Out:
# days_to_departure
# False    331
# True       8
# Name: count, dtype: int64

# %%
advance_bookings = booking[booking['days_to_departure']>0]
advance_bookings.head()
# Out:
#     customer_id   booking_id   from_city from_country            to_city  \
# 0  customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1  customer_303  booking_156       Delhi        India           Brussels
# 2  customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3  customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4  customer_287  booking_222     Gurgaon        India   Roissy-en-France
#
#   to_country          booking_time device_type_used  INR_Amount service_name  \
# 0      India  2020-02-05T16:12:08Z          Desktop     2565.28          MMT
# 1    Belgium  2018-11-21T08:21:47Z          Android    23120.00        YATRA
# 2    Germany  2019-12-16T22:54:58Z          Android    25717.60        YATRA
# 3    Germany  2021-10-29T12:25:38Z          Desktop   135969.60      GOIBIBO
# 4     France  2020-08-11T16:09:10Z          Android    31791.20      GOIBIBO
#
# ...

# %%
(advance_bookings['days_to_departure']==0).value_counts()
# Out:
# days_to_departure
# False    331
# Name: count, dtype: int64

# %%
(advance_bookings['days_to_departure']==0).any()
# Out:
# False

# %%
advance_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331 entries, 0 to 338
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         331 non-null    object
#  1   booking_id          331 non-null    object
#  2   from_city           331 non-null    object
#  3   from_country        331 non-null    object
#  4   to_city             331 non-null    object
#  5   to_country          331 non-null    object
#  6   booking_time        331 non-null    object
#  7   device_type_used    331 non-null    object
#  8   INR_Amount          331 non-null    float64
#  9   service_name        331 non-null    object
#  10  no_of_passengers    331 non-null    float64
#  11  days_to_departure   331 non-null    float64
#  12  distance_km         331 non-null    float64
#  13  booking_time_clear  331 non-null    datetime64[ns, UTC]
#  14  booking_day         331 non-null    object
# ...

# %%
advance_bookings_counts = advance_bookings['from_city'].value_counts()

# %%
advance_bookings_counts[advance_bookings_counts>4]
# Out:
# from_city
# Gurgaon        131
# Mumbai          34
# Delhi           29
# Devanhalli      24
# Rāja Sānsi      17
# Chennai         16
# Ahmedabad        8
# New Delhi        7
# Madhyamgram      6
# Bālāpur          6
# Name: count, dtype: int64

# %%
advance_bookings_counts[:3]
# Out:
# from_city
# Gurgaon    131
# Mumbai      34
# Delhi       29
# Name: count, dtype: int64

# %%
# 7) Plot a heatmap displaying correlations of the numerical column and report which pair of numerical columns in the bookings data set,
# have the maximum correlation?
booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         339 non-null    object
#  1   booking_id          339 non-null    object
#  2   from_city           339 non-null    object
#  3   from_country        339 non-null    object
#  4   to_city             339 non-null    object
#  5   to_country          339 non-null    object
#  6   booking_time        339 non-null    object
#  7   device_type_used    339 non-null    object
#  8   INR_Amount          339 non-null    float64
#  9   service_name        339 non-null    object
#  10  no_of_passengers    339 non-null    float64
#  11  days_to_departure   339 non-null    float64
#  12  distance_km         339 non-null    float64
#  13  booking_time_clear  339 non-null    datetime64[ns, UTC]
#  14  booking_day         339 non-null    object
# ...

# %%
numerical_columns = booking[['INR_Amount', 'no_of_passengers', 'days_to_departure', 'distance_km']]

correlation_matrix = numerical_columns.corr()
correlation_matrix
# Out:
#                    INR_Amount  no_of_passengers  days_to_departure  \
# INR_Amount           1.000000          0.397229           0.284534
# no_of_passengers     0.397229          1.000000           0.187128
# days_to_departure    0.284534          0.187128           1.000000
# distance_km          0.623565          0.001698           0.216972
#
#                    distance_km
# INR_Amount            0.623565
# no_of_passengers      0.001698
# days_to_departure     0.216972
# distance_km           1.000000

# %%
sns.heatmap(correlation_matrix, annot = True)
# Out:
# <Axes: >

# %%
co = correlation_matrix.unstack().drop_duplicates().sort_values(ascending = False)
co
# Out:
# INR_Amount         INR_Amount           1.000000
#                    distance_km          0.623565
#                    no_of_passengers     0.397229
#                    days_to_departure    0.284534
# days_to_departure  distance_km          0.216972
# no_of_passengers   days_to_departure    0.187128
#                    distance_km          0.001698
# dtype: float64

# %%
top_corr_pair =  correlation_matrix.unstack().drop_duplicates().sort_values(ascending = False).index[1] 
top_corr_value = correlation_matrix.unstack().drop_duplicates().sort_values(ascending = False).iloc[1]  

print("Top correlation is between",top_corr_pair[0] ,"and" ,top_corr_pair[1], top_corr_value)
# Out:
# Top correlation is between INR_Amount and distance_km 0.6235653096997817

# %%
# 8) For each service, which is the most used device type for making bookings on the platform?
booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         339 non-null    object
#  1   booking_id          339 non-null    object
#  2   from_city           339 non-null    object
#  3   from_country        339 non-null    object
#  4   to_city             339 non-null    object
#  5   to_country          339 non-null    object
#  6   booking_time        339 non-null    object
#  7   device_type_used    339 non-null    object
#  8   INR_Amount          339 non-null    float64
#  9   service_name        339 non-null    object
#  10  no_of_passengers    339 non-null    float64
#  11  days_to_departure   339 non-null    float64
#  12  distance_km         339 non-null    float64
#  13  booking_time_clear  339 non-null    datetime64[ns, UTC]
#  14  booking_day         339 non-null    object
# ...

# %%
booking.groupby(["service_name", "device_type_used"]).size()
# Out:
# service_name  device_type_used
# GOIBIBO       Android             44
#               Desktop             61
#               IOS                 70
#               MobileWeb           11
# MMT           Android              8
#               Desktop             30
#               IOS                  5
#               MobileWeb            5
# YATRA         Android             18
#               Desktop             51
#               IOS                 22
#               MobileWeb           11
#               Tablet               3
# dtype: int64

# %%
service_device = booking.groupby(["service_name", "device_type_used"]).size().unstack(fill_value=0)
service_device
# Out:
# device_type_used  Android  Desktop  IOS  MobileWeb  Tablet
# service_name
# GOIBIBO                44       61   70         11       0
# MMT                     8       30    5          5       0
# YATRA                  18       51   22         11       3

# %%
most_used_device = service_device.idxmax(axis = 1)
most_used_device
# Out:
# service_name
# GOIBIBO        IOS
# MMT        Desktop
# YATRA      Desktop
# dtype: object

# %%
booking
# Out:
#       customer_id   booking_id   from_city from_country            to_city  \
# 0    customer_259   booking_82     Gurgaon        India          Ahmedabad
# 1    customer_303  booking_156       Delhi        India           Brussels
# 2    customer_203   booking_99  Devanhalli        India  Frankfurt am Main
# 3    customer_211  booking_319     Gurgaon        India  Frankfurt am Main
# 4    customer_287  booking_222     Gurgaon        India   Roissy-en-France
# ..            ...          ...         ...          ...                ...
# 334  customer_133  booking_238     Gurgaon        India         Rāja Sānsi
# 335  customer_235   booking_37     Gurgaon        India        Bhubaneswar
# 336   customer_62  booking_239     Gurgaon        India         Birmingham
# 337    customer_5  booking_131      Mumbai        India             Kloten
# 338  customer_241  booking_336     Gurgaon        India          Amsterdam
#
# ...

# %%
# 9) Plot the trends at a quarterly frequency for the number of bookings by each of the
# device types, that is, plot a time series for each year and quarter showing the
# number of bookings performed by each device type.

booking.set_index('booking_time_clear', inplace=True)

quarterly_device_bookings = booking.groupby('device_type_used').resample('Q').size().unstack(fill_value=0)

quarterly_device_bookings
# Out:
# C:\Users\aiden\AppData\Local\Temp\ipykernel_6996\1799805653.py:7: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   quarterly_device_bookings = booking.groupby('device_type_used').resample('Q').size().unstack(fill_value=0)
# booking_time_clear  2018-09-30 00:00:00+00:00  2018-12-31 00:00:00+00:00  \
# device_type_used
# Android                                     3                          3
# Desktop                                     6                         22
# IOS                                         0                          4
# MobileWeb                                   2                          4
# Tablet                                      1                          1
#
# booking_time_clear  2019-03-31 00:00:00+00:00  2019-06-30 00:00:00+00:00  \
# device_type_used
# Android                                     0                          0
# Desktop                                     1                          1
# ...

# %%
plt.figure(figsize=(14, 18))
quarterly_device_bookings.T.plot(kind='line')
plt.title('Quarterly Number of Bookings by Device Type')
plt.xlabel('Date')
plt.ylabel('Number of Bookings')
plt.legend(title='Device Type')
plt.show()

# %%
# 10) Consider the following example:
# 12 customers performed a total of 100 searches but only a few of them performed
# 10 bookings in total.
# Searches = 100 ,bookings = 10 ,customers = 12
# The overall booking to search ratio, Ober, is 10/100 = 0.1 Using the above
# information/context, answer the following:
# • What is the average oBSR for each month of the year?
# • What is the average oBSR for each day of the week?
# • Plot a time series of oBSR on all the given dates.

merge_booking_session = session.merge(booking, on = 'booking_id', how = 'left')
merge_booking_session
# Out:
#        session_id    search_id               search_time  \
# 0     session_322   search_784  2020-01-21T21:35:38.910Z
# 1     session_322   search_776  2020-01-21T21:37:37.697Z
# 2     session_322   search_623  2020-01-21T21:36:11.392Z
# 3     session_322   search_270  2020-01-21T21:16:07.685Z
# 4     session_322   search_905  2020-01-21T21:34:55.673Z
# ...           ...          ...                       ...
# 1492  session_150   search_156  2018-12-18T22:59:43.764Z
# 1493  session_120  search_1096      2021-12-23T17:29:37Z
# 1494  session_120   search_962      2021-12-23T17:34:39Z
# 1495  session_150  search_1306  2018-12-18T22:52:37.654Z
# 1496  session_120  search_1180      2021-12-23T17:34:52Z
#
#          session_starting_time   booking_id   customer_id  from_city  \
# 0         2020-01-21T21:10:12Z          NaN           NaN        NaN
# 1         2020-01-21T21:10:12Z          NaN           NaN        NaN
# 2         2020-01-21T21:10:12Z          NaN           NaN        NaN
# ...

# %%
merge_booking_session.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   session_id             1497 non-null   object
#  1   search_id              1497 non-null   object
#  2   search_time            1497 non-null   object
#  3   session_starting_time  1497 non-null   object
#  4   booking_id             366 non-null    object
#  5   customer_id            366 non-null    object
#  6   from_city              366 non-null    object
#  7   from_country           366 non-null    object
#  8   to_city                366 non-null    object
#  9   to_country             366 non-null    object
#  10  booking_time           366 non-null    object
#  11  device_type_used       366 non-null    object
#  12  INR_Amount             366 non-null    float64
#  13  service_name           366 non-null    object
# ...

# %%
merge_booking_session['search_time'] = pd.to_datetime(merge_booking_session['search_time'], errors='coerce')
merge_booking_session['booking_time'] = pd.to_datetime(merge_booking_session['booking_time'], errors='coerce')

daily_searches = merge_booking_session.groupby(merge_booking_session['search_time'].dt.date).size()
daily_searches
# Out:
# search_time
# 2018-09-04     3
# 2018-09-11     2
# 2018-09-21     5
# 2018-09-23     1
# 2018-09-24     3
#               ..
# 2020-03-16    14
# 2020-03-18    10
# 2020-03-19     8
# 2020-03-20     3
# 2020-03-21     1
# Length: 129, dtype: int64

# %%
daily_bookings =merge_booking_session.groupby(merge_booking_session['booking_time'].dt.date).size()
print("Daily Bookings are : \n\n",daily_bookings)
# Out:
# Daily Bookings are :
#
#  booking_time
# 2018-09-04    1
# 2018-09-11    2
# 2018-09-21    2
# 2018-09-23    1
# 2018-09-24    1
#              ..
# 2022-06-04    1
# 2022-06-29    2
# 2022-07-01    1
# 2022-07-06    1
# 2022-07-11    2
# Length: 257, dtype: int64

# %%
daily_oBSR = daily_bookings/daily_searches
print("Daily oBSR are : \n\n",daily_oBSR)
# Out:
# Daily oBSR are :
#
#  2018-09-04    0.333333
# 2018-09-11    1.000000
# 2018-09-21    0.400000
# 2018-09-23    1.000000
# 2018-09-24    0.333333
#                 ...
# 2022-06-04         NaN
# 2022-06-29         NaN
# 2022-07-01         NaN
# 2022-07-06         NaN
# 2022-07-11         NaN
# Length: 258, dtype: float64

# %%
daily_oBSR.index = pd.to_datetime(daily_oBSR.index)
monthly_oBSR = daily_oBSR.resample('M').mean()
print("Monthly oBSR are : \n\n",monthly_oBSR)
# Out:
# Monthly oBSR are :
#
#  2018-09-30    0.518681
# 2018-10-31    0.221212
# 2018-11-30    0.535828
# 2018-12-31    0.407937
# 2019-01-31    0.400000
# 2019-02-28         NaN
# 2019-03-31         NaN
# 2019-04-30         NaN
# 2019-05-31         NaN
# 2019-06-30    1.000000
# 2019-07-31    0.235606
# 2019-08-31    0.350000
# 2019-09-30    0.677656
# 2019-10-31    0.602561
# 2019-11-30    0.610746
# 2019-12-31    0.464010
# 2020-01-31    0.304959
# 2020-02-29    0.466192
# 2020-03-31    0.502513
# 2020-04-30         NaN
# 2020-05-31         NaN
# 2020-06-30         NaN
# 2020-07-31         NaN
# 2020-08-31         NaN
# 2020-09-30         NaN
# 2020-10-31         NaN
# 2020-11-30         NaN
# 2020-12-31         NaN
# 2021-01-31         NaN
# 2021-02-28         NaN
# 2021-03-31         NaN
# 2021-04-30         NaN
# 2021-05-31         NaN
# 2021-06-30         NaN
# 2021-07-31         NaN
# 2021-08-31         NaN
# 2021-09-30         NaN
# 2021-10-31         NaN
# 2021-11-30         NaN
# ...

# %%
day_oBSR = daily_oBSR.groupby(daily_oBSR.index.day_name()).mean()
print("Day oBSR are : \n\n",day_oBSR)
# Out:
# Day oBSR are :
#
#  Friday       0.420565
# Monday       0.427265
# Saturday     0.429127
# Sunday       0.525412
# Thursday     0.527210
# Tuesday      0.447253
# Wednesday    0.382970
# dtype: float64

# %%
plt.figure(figsize=(14,8))
daily_oBSR.plot(kind = 'line')
plt.title('Time Series of Overall Booking to Search Ratio (oBSR)')
plt.xlabel('Date')
plt.ylabel('oBSR')
plt.grid(True)
plt.show()

# %%
day_bookings =merge_booking_session.groupby(merge_booking_session['booking_day']).size()
print("Day Bookings are : \n\n",day_bookings)
# Out:
# Day Bookings are :
#
#  booking_day
# Friday       57
# Monday       54
# Saturday     49
# Sunday       38
# Thursday     70
# Tuesday      62
# Wednesday    36
# dtype: int64

# %%
merge_booking_session['search_day'] = merge_booking_session['search_time'].dt.day_name()
merge_booking_session
# Out:
#        session_id    search_id                      search_time  \
# 0     session_322   search_784 2020-01-21 21:35:38.910000+00:00
# 1     session_322   search_776 2020-01-21 21:37:37.697000+00:00
# 2     session_322   search_623 2020-01-21 21:36:11.392000+00:00
# 3     session_322   search_270 2020-01-21 21:16:07.685000+00:00
# 4     session_322   search_905 2020-01-21 21:34:55.673000+00:00
# ...           ...          ...                              ...
# 1492  session_150   search_156 2018-12-18 22:59:43.764000+00:00
# 1493  session_120  search_1096                              NaT
# 1494  session_120   search_962                              NaT
# 1495  session_150  search_1306 2018-12-18 22:52:37.654000+00:00
# 1496  session_120  search_1180                              NaT
#
#          session_starting_time   booking_id   customer_id  from_city  \
# 0         2020-01-21T21:10:12Z          NaN           NaN        NaN
# ...

# %%
day_search = merge_booking_session.groupby(merge_booking_session['search_day']).size()
day_search
# Out:
# search_day
# Friday       137
# Monday       152
# Saturday     137
# Sunday        58
# Thursday     188
# Tuesday      146
# Wednesday    106
# dtype: int64

# %%
day_oBSR = day_bookings/day_search
day_oBSR
# Out:
# booking_day
# Friday       0.416058
# Monday       0.355263
# Saturday     0.357664
# Sunday       0.655172
# Thursday     0.372340
# Tuesday      0.424658
# Wednesday    0.339623
# dtype: float64
